# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df_irfaan = pd.read_csv('My Uber Drives 2016.csv')

# %%
df_irfaan
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
df_irfaan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
df_irfaan.describe()
# Out:
#              MILES*
# count   1156.000000
# mean      21.115398
# std      359.299007
# min        0.500000
# 25%        2.900000
# 50%        6.000000
# 75%       10.400000
# max    12204.700000

# %%
df_irfaan.groupby(["START*", "STOP*"])[['MILES*']].sum().sort_values(['MILES*'], ascending=False).head()
# Out:
#                                    MILES*
# START*           STOP*
# Unknown Location Unknown Location  1360.8
# Morrisville      Cary               395.7
# Cary             Durham             390.0
#                  Morrisville        380.0
# Raleigh          Cary               365.7

# %%
df_irfaan['CATEGORY*'].unique()
# Out:
# array(['Business', 'Personal', nan], dtype=object)

# %%
df_irfaan.groupby(["CATEGORY*", "PURPOSE*"])[['MILES*']].sum().sort_values(['MILES*'], ascending=False)
# Out:
#                            MILES*
# CATEGORY* PURPOSE*
# Business  Meeting          2851.3
#           Customer Visit   2089.5
#           Meal/Entertain    911.7
#           Temporary Site    523.7
#           Errand/Supplies   508.0
#           Between Offices   197.0
# Personal  Commute           180.2
#           Moving             18.2
# Business  Airport/Travel     16.5
# Personal  Charity ($)        15.1

# %%
sns.countplot(df_irfaan['CATEGORY*'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(15,8))
sns.countplot(df_irfaan['PURPOSE*'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(20,6))
sns.countplot(df_irfaan['STOP*'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
